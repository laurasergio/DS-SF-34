# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 37)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv("/Users/lsergio/DS-SF-34/classes/06/datasets/dataset-06-storms.csv")

# %%
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df.shape[1]
# Out:
# 37

# %%
df.describe
# Out:
# <bound method DataFrame.describe of         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df.columns
# Out:
# Index([u'STATE__', u'BGN_DATE', u'BGN_TIME', u'TIME_ZONE', u'COUNTY',
#        u'COUNTYNAME', u'STATE', u'EVTYPE', u'BGN_RANGE', u'BGN_AZI',
#        u'BGN_LOCATI', u'END_DATE', u'END_TIME', u'COUNTY_END', u'COUNTYENDN',
#        u'END_RANGE', u'END_AZI', u'END_LOCATI', u'LENGTH', u'WIDTH', u'F',
#        u'MAG', u'FATALITIES', u'INJURIES', u'PROPDMG', u'PROPDMGEXP',
#        u'CROPDMG', u'CROPDMGEXP', u'WFO', u'STATEOFFIC', u'ZONENAMES',
#        u'LATITUDE', u'LONGITUDE', u'LATITUDE_E', u'LONGITUDE_', u'REMARKS',
#        u'REFNUM'],
#       dtype='object')

# %%
df.corr()
# Out:
#              STATE__    COUNTY  BGN_RANGE  COUNTY_END  COUNTYENDN    ...     \
# STATE__     1.000000  0.306231   0.045905         NaN         NaN    ...
# COUNTY      0.306231  1.000000   0.054419         NaN         NaN    ...
# BGN_RANGE   0.045905  0.054419   1.000000         NaN         NaN    ...
# COUNTY_END       NaN       NaN        NaN         NaN         NaN    ...
# COUNTYENDN       NaN       NaN        NaN         NaN         NaN    ...
# ...              ...       ...        ...         ...         ...    ...
# LATITUDE   -0.006642  0.034407   0.071263         NaN         NaN    ...
# LONGITUDE  -0.024199  0.097044   0.089530         NaN         NaN    ...
# LATITUDE_E -0.029509  0.007791   0.111696         NaN         NaN    ...
# LONGITUDE_ -0.039056  0.032864   0.123731         NaN         NaN    ...
# REFNUM      0.090742  0.017981   0.115187         NaN         NaN    ...
#
#             LATITUDE  LONGITUDE  LATITUDE_E  LONGITUDE_    REFNUM
# ...

# %%
df.plot(kind = 'box')

# %%
df.STATE__.plot(kind = 'box', figsize = (8, 8))

# %%
df.shape[0]
# Out:
# 902297

# %%
list(df)
# Out:
# ['STATE__',
#  'BGN_DATE',
#  'BGN_TIME',
#  'TIME_ZONE',
#  'COUNTY',
#  'COUNTYNAME',
#  'STATE',
#  'EVTYPE',
#  'BGN_RANGE',
#  'BGN_AZI',
#  'BGN_LOCATI',
#  'END_DATE',
#  'END_TIME',
#  'COUNTY_END',
#  'COUNTYENDN',
#  'END_RANGE',
#  'END_AZI',
#  'END_LOCATI',
#  'LENGTH',
#  'WIDTH',
#  'F',
#  'MAG',
#  'FATALITIES',
#  'INJURIES',
#  'PROPDMG',
#  'PROPDMGEXP',
#  'CROPDMG',
#  'CROPDMGEXP',
#  'WFO',
#  'STATEOFFIC',
#  'ZONENAMES',
#  'LATITUDE',
#  'LONGITUDE',
#  'LATITUDE_E',
#  'LONGITUDE_',
#  'REMARKS',
#  'REFNUM']

# %%
df.REFNUM.plot(kind = 'box', figsize = (8, 8))

# %%
df.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-bdc1d976d3a6> in <module>()
# ----> 1 df.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
dd
# Out:
# STATE__                                                      95
# BGN_DATE                                       9/9/2011 0:00:00
# BGN_TIME                                                   2400
# TIME_ZONE                                                   UTC
# COUNTY                                                      873
#                                     ...
# LONGITUDE                                                 17124
# LATITUDE_E                                                 9706
# LONGITUDE_                                               106220
# REMARKS       wires down\rA strong spring storm system moved...
# REFNUM                                                   902297
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 902297

# %%
for column in df.columns:
    print column
# Out:
# STATE__
# BGN_DATE
# BGN_TIME
# TIME_ZONE
# COUNTY
# COUNTYNAME
# STATE
# EVTYPE
# BGN_RANGE
# BGN_AZI
# BGN_LOCATI
# END_DATE
# END_TIME
# COUNTY_END
# COUNTYENDN
# END_RANGE
# END_AZI
# END_LOCATI
# LENGTH
# WIDTH
# F
# MAG
# FATALITIES
# INJURIES
# PROPDMG
# PROPDMGEXP
# CROPDMG
# CROPDMGEXP
# WFO
# STATEOFFIC
# ZONENAMES
# LATITUDE
# LONGITUDE
# LATITUDE_E
# LONGITUDE_
# REMARKS
# REFNUM

# %%
df.isnull().sum()
# Out:
# STATE__            0
# BGN_DATE           0
# BGN_TIME           0
# TIME_ZONE          0
# COUNTY             0
#                ...
# LONGITUDE          0
# LATITUDE_E        40
# LONGITUDE_         0
# REMARKS       287433
# REFNUM             0
# dtype: int64

# %%
df.COUNTYNAME.value_counts()
# Out:
# JEFFERSON                                                                               7840
# WASHINGTON                                                                              7603
# JACKSON                                                                                 6660
# FRANKLIN                                                                                6256
# LINCOLN                                                                                 5937
#                                                                                         ...
# NDZ019>021 - 034 - 042 - 045                                                               1
# MSZ036 - 042>045 - 047>048 - 050 - 052 - 054>055 - 057>058 - 061>062 - 066 - 072>074       1
# FLZ076 - 076                                                                               1
# TXZ230>234 - 240>247                                                                       1
# ...

# %%
df.groupby('COUNTYNAME').sum()
# Out:
#                                                 STATE__   COUNTY  BGN_RANGE  \
# COUNTYNAME
# 5NM E OF MACKINAC BRIDGE TO PRESQUE ISLE LT MI   3510.0  13533.0       84.0
# ABBEVILLE                                       10125.0    225.0      282.0
# ABBEVILLE AND LAURENS                              45.0      1.0        0.0
# ACADIA                                           5324.0    242.0      222.0
# ACCOMACK                                         5151.0    101.0      270.0
# ...                                                 ...      ...        ...
# ZAPATA AND STARR                                   48.0    505.0        0.0
# ZAVALA                                           6048.0  63882.0      161.1
# ZEIBACH                                            92.0    274.0       25.0
# ZIEBACH                                         12880.0  38360.0     1968.0
# ZIEBACH AND HAAKON                                 46.0    137.0        0.0
#
# ...

# %%
df.groupby('FATALITIES').sum()
# Out:
#                STATE__      COUNTY   BGN_RANGE  COUNTY_END  COUNTYENDN  \
# FATALITIES
# 0.0         27950083.0  90241911.0  1333039.78         0.0         NaN
# 1.0           144564.0    410929.0     4447.30         0.0         NaN
# 2.0            29361.0     80783.0      778.20         0.0         NaN
# 3.0             9797.0     25288.0      194.90         0.0         NaN
# 4.0             5107.0     12118.0      111.30         0.0         NaN
# ...                ...         ...         ...         ...         ...
# 99.0              17.0         5.0        0.00         0.0         NaN
# 114.0             48.0       309.0        0.00         0.0         NaN
# 116.0             26.0        49.0        0.00         0.0         NaN
# 158.0             29.0        97.0        2.00         0.0         NaN
# 583.0             17.0         0.0        0.00         0.0         NaN
#
#                 ...           LATITUDE     LONGITUDE    LATITUDE_E  \
# FATALITIES      ...
# ...

# %%
len(df.groupby(['FATALITIES', 'COUNTY']))
# Out:
# 1652

# %%
df.FATALITIES.value_counts()
# Out:
# 0.0     895323
# 1.0       5010
# 2.0        996
# 3.0        314
# 4.0        166
#          ...
# 50.0         1
# 26.0         1
# 99.0         1
# 90.0         1
# 67.0         1
# Name: FATALITIES, dtype: int64

# %%
len(df.groupby(['FATALITIES', 'EVTYPE']))
# Out:
# 1400

# %%
len(df.groupby(['FATALITIES']))
# Out:
# 52

# %%
df.groupby('EVTYPE').FATALITIES.sum()
# Out:
# EVTYPE
#    HIGH SURF ADVISORY      0.0
#  COASTAL FLOOD             0.0
#  FLASH FLOOD               0.0
#  LIGHTNING                 0.0
#  TSTM WIND                 0.0
#  TSTM WIND (G45)           0.0
#  WATERSPOUT                0.0
#  WIND                      0.0
# ?                          0.0
# ABNORMAL WARMTH            0.0
# ABNORMALLY DRY             0.0
# ABNORMALLY WET             0.0
# ACCUMULATED SNOWFALL       0.0
# AGRICULTURAL FREEZE        0.0
# APACHE COUNTY              0.0
# ASTRONOMICAL HIGH TIDE     0.0
# ASTRONOMICAL LOW TIDE      0.0
# AVALANCE                   1.0
#                           ...
# WINTER WEATHER MIX         0.0
# WINTER WEATHER/MIX        28.0
# WINTERY MIX                0.0
# WINTRY MIX                 1.0
# WND                        0.0
# Wet Month                  0.0
# Wet Year                   0.0
# Whirlwind                  1.0
# Wind                       0.0
# Wind Damage                0.0
# Winter Weather             0.0
# ...

# %%
df.FATALITIES.max()
# Out:
# 583.0

# %%
df.INJURIES.max()
# Out:
# 1700.0

# %%
df_temp = df[["EVTYPE","FATALITIES","INJURIES","PROPDMG","CROPDMG", "PROPDMGEXP", "CROPDMGEXP"]]

# %%
df_temp
# Out:
#                 EVTYPE  FATALITIES  INJURIES  PROPDMG  CROPDMG PROPDMGEXP  \
# 0              TORNADO         0.0      15.0    25.00      0.0          K
# 1              TORNADO         0.0       0.0     2.50      0.0          K
# 2              TORNADO         0.0       2.0    25.00      0.0          K
# 3              TORNADO         0.0       2.0     2.50      0.0          K
# 4              TORNADO         0.0       2.0     2.50      0.0          K
# 5              TORNADO         0.0       6.0     2.50      0.0          K
# 6              TORNADO         0.0       1.0     2.50      0.0          K
# 7              TORNADO         0.0       0.0     2.50      0.0          K
# 8              TORNADO         1.0      14.0    25.00      0.0          K
# 9              TORNADO         0.0       0.0    25.00      0.0          K
# 10             TORNADO         0.0       3.0     2.50      0.0          M
# 11             TORNADO         0.0       3.0     2.50      0.0          M
# ...

# %%
df_temp.FATALITIES.max()
# Out:
# 583.0

# %%
df_temp.groupby('EVTYPE').FATALITIES.sum()
# Out:
# EVTYPE
#    HIGH SURF ADVISORY      0.0
#  COASTAL FLOOD             0.0
#  FLASH FLOOD               0.0
#  LIGHTNING                 0.0
#  TSTM WIND                 0.0
#  TSTM WIND (G45)           0.0
#  WATERSPOUT                0.0
#  WIND                      0.0
# ?                          0.0
# ABNORMAL WARMTH            0.0
# ABNORMALLY DRY             0.0
# ABNORMALLY WET             0.0
# ACCUMULATED SNOWFALL       0.0
# AGRICULTURAL FREEZE        0.0
# APACHE COUNTY              0.0
# ASTRONOMICAL HIGH TIDE     0.0
# ASTRONOMICAL LOW TIDE      0.0
# AVALANCE                   1.0
#                           ...
# WINTER WEATHER MIX         0.0
# WINTER WEATHER/MIX        28.0
# WINTERY MIX                0.0
# WINTRY MIX                 1.0
# WND                        0.0
# Wet Month                  0.0
# Wet Year                   0.0
# Whirlwind                  1.0
# Wind                       0.0
# Wind Damage                0.0
# Winter Weather             0.0
# ...

# %%
(df_temp.EVTYPE == 'WINTER WEATHER/MIX').sum()
# Out:
# 1104

# %%
df_temp.groupby('EVTYPE').max()
# Out:
#                                 FATALITIES  INJURIES  PROPDMG PROPDMGEXP  \
# EVTYPE
#    HIGH SURF ADVISORY                  0.0       0.0    200.0          K
#  COASTAL FLOOD                         0.0       0.0      0.0        NaN
#  FLASH FLOOD                           0.0       0.0     50.0          K
#  LIGHTNING                             0.0       0.0      0.0        NaN
#  TSTM WIND                             0.0       0.0    100.0          M
#  TSTM WIND (G45)                       0.0       0.0      8.0          K
#  WATERSPOUT                            0.0       0.0      0.0        NaN
#  WIND                                  0.0       0.0      0.0        NaN
# ?                                      0.0       0.0      5.0          K
# ABNORMAL WARMTH                        0.0       0.0      0.0        NaN
# ABNORMALLY DRY                         0.0       0.0      0.0        NaN
# ABNORMALLY WET                         0.0       0.0      0.0        NaN
# ...

# %%
df_temp.isnull().sum()
# Out:
# EVTYPE             0
# FATALITIES         0
# INJURIES           0
# PROPDMG            0
# PROPDMGEXP    465934
# CROPDMGEXP    618413
# dtype: int64

# %%
len(df_temp)
# Out:
# 902297

# %%
df_temp.shape[1]
# Out:
# 6

# %%
df_temp.FATALITIES.hist(figsize = (8, 8))

# %%
df.plot.scatter(x = 'FATALITIES', y = 'INJURIES', s = 100, figsize = (8, 8))

# %%
df.plot.scatter(x = 'INJURIES', y = 'FATALITIES', s = 100, figsize = (8, 8))

# %%
color = df_temp.EVTYPE.map({'TORNADO': 'blue', 'WINTER STORM': 'red', 'HIGH WIND': 'green'})

# %%
df_temp
# Out:
#                 EVTYPE  FATALITIES  INJURIES  PROPDMG  CROPDMG PROPDMGEXP  \
# 0              TORNADO         0.0      15.0    25.00      0.0          K
# 1              TORNADO         0.0       0.0     2.50      0.0          K
# 2              TORNADO         0.0       2.0    25.00      0.0          K
# 3              TORNADO         0.0       2.0     2.50      0.0          K
# 4              TORNADO         0.0       2.0     2.50      0.0          K
# 5              TORNADO         0.0       6.0     2.50      0.0          K
# 6              TORNADO         0.0       1.0     2.50      0.0          K
# 7              TORNADO         0.0       0.0     2.50      0.0          K
# 8              TORNADO         1.0      14.0    25.00      0.0          K
# 9              TORNADO         0.0       0.0    25.00      0.0          K
# 10             TORNADO         0.0       3.0     2.50      0.0          M
# 11             TORNADO         0.0       3.0     2.50      0.0          M
# ...

# %%
df.EVTYPE.unique()
# Out:
# array(['TORNADO', 'TSTM WIND', 'HAIL', 'FREEZING RAIN', 'SNOW',
#        'ICE STORM/FLASH FLOOD', 'SNOW/ICE', 'WINTER STORM',
#        'HURRICANE OPAL/HIGH WINDS', 'THUNDERSTORM WINDS', 'RECORD COLD',
#        'HURRICANE ERIN', 'HURRICANE OPAL', 'HEAVY RAIN', 'LIGHTNING',
#        'THUNDERSTORM WIND', 'DENSE FOG', 'RIP CURRENT',
#        'THUNDERSTORM WINS', 'FLASH FLOOD', 'FLASH FLOODING', 'HIGH WINDS',
#        'FUNNEL CLOUD', 'TORNADO F0', 'THUNDERSTORM WINDS LIGHTNING',
#        'THUNDERSTORM WINDS/HAIL', 'HEAT', 'WIND', 'LIGHTING',
#        'HEAVY RAINS', 'LIGHTNING AND HEAVY RAIN', 'FUNNEL', 'WALL CLOUD',
#        'FLOODING', 'THUNDERSTORM WINDS HAIL', 'FLOOD', 'COLD',
#        'HEAVY RAIN/LIGHTNING', 'FLASH FLOODING/THUNDERSTORM WI',
#        'WALL CLOUD/FUNNEL CLOUD', 'THUNDERSTORM', 'WATERSPOUT',
#        'EXTREME COLD', 'HAIL 1.75)', 'LIGHTNING/HEAVY RAIN', 'HIGH WIND',
#        'BLIZZARD', 'BLIZZARD WEATHER', 'WIND CHILL', 'BREAKUP FLOODING',
# ...

# %%
vcounts = df.EVTYPE.value_counts()
vcounts.t

# %%
zip(vcounts.to_frame().index, vcounts.to_frame().values)
# Out:
# [('HAIL', array([288661])),
#  ('TSTM WIND', array([219940])),
#  ('THUNDERSTORM WIND', array([82563])),
#  ('TORNADO', array([60652])),
#  ('FLASH FLOOD', array([54277])),
#  ('FLOOD', array([25326])),
#  ('THUNDERSTORM WINDS', array([20843])),
#  ('HIGH WIND', array([20212])),
#  ('LIGHTNING', array([15754])),
#  ('HEAVY SNOW', array([15708])),
#  ('HEAVY RAIN', array([11723])),
#  ('WINTER STORM', array([11433])),
#  ('WINTER WEATHER', array([7026])),
#  ('FUNNEL CLOUD', array([6839])),
#  ('MARINE TSTM WIND', array([6175])),
#  ('MARINE THUNDERSTORM WIND', array([5812])),
#  ('WATERSPOUT', array([3796])),
#  ('STRONG WIND', array([3566])),
#  ('URBAN/SML STREAM FLD', array([3392])),
#  ('WILDFIRE', array([2761])),
#  ('BLIZZARD', array([2719])),
#  ('DROUGHT', array([2488])),
#  ('ICE STORM', array([2006])),
#  ('EXCESSIVE HEAT', array([1678])),
#  ('HIGH WINDS', array([1533])),
#  ('WILD/FOREST FIRE', array([1457])),
#  ('FROST/FREEZE', array([1342])),
# ...

# %%
vcounts.to_frame()
# Out:
#                                 EVTYPE
# HAIL                            288661
# TSTM WIND                       219940
# THUNDERSTORM WIND                82563
# TORNADO                          60652
# FLASH FLOOD                      54277
# FLOOD                            25326
# THUNDERSTORM WINDS               20843
# HIGH WIND                        20212
# LIGHTNING                        15754
# HEAVY SNOW                       15708
# HEAVY RAIN                       11723
# WINTER STORM                     11433
# WINTER WEATHER                    7026
# FUNNEL CLOUD                      6839
# MARINE TSTM WIND                  6175
# MARINE THUNDERSTORM WIND          5812
# WATERSPOUT                        3796
# STRONG WIND                       3566
# URBAN/SML STREAM FLD              3392
# WILDFIRE                          2761
# BLIZZARD                          2719
# DROUGHT                           2488
# ICE STORM                         2006
# ...

# %%
for damage in PROPDMG:
    if damage == 0:
        print damage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-be6f9fd9cf84> in <module>()
# ----> 1 for damage in PROPDMG:
#       2     if damage == 0:
#       3         print damage
#
# NameError: name 'PROPDMG' is not defined

# %%
df_temp
# Out:
#                 EVTYPE  FATALITIES  INJURIES  PROPDMG  CROPDMG PROPDMGEXP  \
# 0              TORNADO         0.0      15.0    25.00      0.0          K
# 1              TORNADO         0.0       0.0     2.50      0.0          K
# 2              TORNADO         0.0       2.0    25.00      0.0          K
# 3              TORNADO         0.0       2.0     2.50      0.0          K
# 4              TORNADO         0.0       2.0     2.50      0.0          K
# 5              TORNADO         0.0       6.0     2.50      0.0          K
# 6              TORNADO         0.0       1.0     2.50      0.0          K
# 7              TORNADO         0.0       0.0     2.50      0.0          K
# 8              TORNADO         1.0      14.0    25.00      0.0          K
# 9              TORNADO         0.0       0.0    25.00      0.0          K
# 10             TORNADO         0.0       3.0     2.50      0.0          M
# 11             TORNADO         0.0       3.0     2.50      0.0          M
# ...

# %%
for damage in PROPDMG:
    if damage >= 0:
        print PROPDMG
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-3bc61adfe0b2> in <module>()
# ----> 1 for damage in PROPDMG:
#       2     if damage >= 0:
#       3         print PROPDMG
#
# NameError: name 'PROPDMG' is not defined

# %%
len(df[df.PROPDMG == 0])
# Out:
# 663123

# %%
df[df.PROPDMG == 0]
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 13          1.0   2/29/1952 0:00:00         1700       CST    49.0
# 53          1.0   3/21/1955 0:00:00         1800       CST    73.0
# 54          1.0   3/25/1955 0:00:00         1610       CST   103.0
# 55          1.0   3/25/1955 0:00:00         1700       CST    83.0
# 56          1.0    4/6/1955 0:00:00          600       CST    73.0
# 57          1.0    4/6/1955 0:00:00         1730       CST    57.0
# 58          1.0    4/6/1955 0:00:00         1816       CST     9.0
# 59          1.0    4/6/1955 0:00:00         1830       CST    63.0
# 60          1.0    4/6/1955 0:00:00         1845       CST    73.0
# 61          1.0    4/6/1955 0:00:00         1930       CST    21.0
# 62          1.0    4/6/1955 0:00:00         1940       CST   123.0
# 63          1.0   4/13/1955 0:00:00          800       CST    63.0
# 64          1.0   4/13/1955 0:00:00         1330       CST    33.0
# ...

# %%
df_temp.groupby(['EVTYPE', 'PROPDMG'])
